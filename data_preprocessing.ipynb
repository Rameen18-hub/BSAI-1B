# %%
import pandas as pd

# %%
df = pd.read_csv("apple_sales_2024.csv")

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.head(4)
# Out:
#        State         Region  iPhone Sales (in million units)  \
# 0  Chongqing  Greater China                             7.46
# 1    Germany         Europe                             8.63
# 2         UK         Europe                             5.61
# 3   Shanghai  Greater China                             7.82
#
#    iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                           6.75                          1.19
# 1                          14.06                          7.03
# 2                          14.09                          8.78
# 3                           7.97                          9.78
#
#    Wearables (in million units)  Services Revenue (in billion $)
# 0                          5.88                            15.88
# 1                          7.42                            10.12
# 2                          8.19                            19.85
# 3                          2.28                             6.16

# %%
df.tail(3)
# Out:
#         State         Region  iPhone Sales (in million units)  \
# 997   Germany         Europe                            25.47
# 998  Shenzhen  Greater China                            15.34
# 999  Shanghai  Greater China                            26.30
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 997                           7.69                          7.90
# 998                           8.81                          8.24
# 999                           4.06                          3.41
#
#      Wearables (in million units)  Services Revenue (in billion $)
# 997                          6.90                            15.00
# 998                          8.78                            15.49
# 999                          5.69                            14.29

# %% [markdown]
# ## Renaming Columns

# %%
df.rename
# Out:
# <bound method DataFrame.rename of        COuntry         Region  iPhone Sales (in million units)  \
# 0    Chongqing  Greater China                             7.46
# 1      Germany         Europe                             8.63
# 2           UK         Europe                             5.61
# 3     Shanghai  Greater China                             7.82
# 4     Thailand   Rest of Asia                            16.70
# ..         ...            ...                              ...
# 995     Mexico  Rest of World                            29.86
# 996      Texas  North America                            27.83
# 997    Germany         Europe                            25.47
# 998   Shenzhen  Greater China                            15.34
# 999   Shanghai  Greater China                            26.30
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                             6.75                          1.19
# ...

# %%
df.rename(columns={"Country":"State"})
# Out:
#          State         Region  iPhone Sales (in million units)  \
# 0    Chongqing  Greater China                             7.46
# 1      Germany         Europe                             8.63
# 2           UK         Europe                             5.61
# 3     Shanghai  Greater China                             7.82
# 4     Thailand   Rest of Asia                            16.70
# ..         ...            ...                              ...
# 995     Mexico  Rest of World                            29.86
# 996      Texas  North America                            27.83
# 997    Germany         Europe                            25.47
# 998   Shenzhen  Greater China                            15.34
# 999   Shanghai  Greater China                            26.30
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# 0                             6.75                          1.19
# 1                            14.06                          7.03
# ...

# %%
df.rename(columns={"State":"State"},inplace=True)

# %%
df.columns
# Out:
# Index(['State', 'Region', 'iPhone Sales (in million units)',
#        'iPad Sales (in million units)', 'Mac Sales (in million units)',
#        'Wearables (in million units)', 'Services Revenue (in billion $)'],
#       dtype='object')

# %% [markdown]
# ## Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   COuntry                          1000 non-null   object
#  1   Region                           1000 non-null   object
#  2   iPhone Sales (in million units)  1000 non-null   float64
#  3   iPad Sales (in million units)    1000 non-null   float64
#  4   Mac Sales (in million units)     1000 non-null   float64
#  5   Wearables (in million units)     1000 non-null   float64
#  6   Services Revenue (in billion $)  1000 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 54.8+ KB

# %%
df.info(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   COuntry                          1000 non-null   object
#  1   Region                           1000 non-null   object
#  2   iPhone Sales (in million units)  1000 non-null   float64
#  3   iPad Sales (in million units)    1000 non-null   float64
#  4   Mac Sales (in million units)     1000 non-null   float64
#  5   Wearables (in million units)     1000 non-null   float64
#  6   Services Revenue (in billion $)  1000 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 54.8+ KB

# %%
df.describe()
# Out:
#        iPhone Sales (in million units)  iPad Sales (in million units)  \
# count                      1000.000000                    1000.000000
# mean                         17.444500                       8.565880
# std                           7.180077                       3.735994
# min                           5.030000                       2.020000
# 25%                          11.447500                       5.432500
# 50%                          17.130000                       8.695000
# 75%                          23.715000                      11.740000
# max                          29.940000                      14.990000
#
#        Mac Sales (in million units)  Wearables (in million units)  \
# count                   1000.000000                   1000.000000
# mean                       5.555760                      6.935500
# std                        2.506491                      2.951677
# min                        1.010000                      2.000000
# ...

# %%
df.describe(include="all")
# Out:
#           COuntry         Region  iPhone Sales (in million units)  \
# count        1000           1000                      1000.000000
# unique         25              5                              NaN
# top     Hong Kong  Rest of World                              NaN
# freq           50            221                              NaN
# mean          NaN            NaN                        17.444500
# std           NaN            NaN                         7.180077
# min           NaN            NaN                         5.030000
# 25%           NaN            NaN                        11.447500
# 50%           NaN            NaN                        17.130000
# 75%           NaN            NaN                        23.715000
# max           NaN            NaN                        29.940000
#
#         iPad Sales (in million units)  Mac Sales (in million units)  \
# count                     1000.000000                   1000.000000
# ...

# %%
a=df['Region'] #a is series
a.head(5)
# Out:
# 0    Greater China
# 1           Europe
# 2           Europe
# 3    Greater China
# 4     Rest of Asia
# Name: Region, dtype: object

# %%
b=df[["State","Region"]]
b.head()
# Out:
#      COuntry         Region
# 0  Chongqing  Greater China
# 1    Germany         Europe
# 2         UK         Europe
# 3   Shanghai  Greater China
# 4   Thailand   Rest of Asia

# %%
df['State']
# Out:
# 0      Chongqing
# 1        Germany
# 2             UK
# 3       Shanghai
# 4       Thailand
#          ...
# 995       Mexico
# 996        Texas
# 997      Germany
# 998     Shenzhen
# 999     Shanghai
# Name: State, Length: 1000, dtype: object

# %% [markdown]
# ## Data Aggregation

# %%
df['Region'].value_counts()
# Out:
# Region
# Rest of World    221
# Greater China    219
# Europe           204
# Rest of Asia     178
# North America    178
# Name: count, dtype: int64

# %%
df.describe(include="all").iloc[[0,10]]
# Out:
#       State Region  iPhone Sales (in million units)  \
# count  1000   1000                          1000.00
# max     NaN    NaN                            29.94
#
#        iPad Sales (in million units)  Mac Sales (in million units)  \
# count                        1000.00                       1000.00
# max                            14.99                          9.99
#
#        Wearables (in million units)  Services Revenue (in billion $)
# count                        1000.0                          1000.00
# max                            12.0                            19.92

# %%
df.describe(include="all").loc[["min","max"]]
# Out:
#     State Region  iPhone Sales (in million units)  \
# min   NaN    NaN                             5.03
# max   NaN    NaN                            29.94
#
#      iPad Sales (in million units)  Mac Sales (in million units)  \
# min                           2.02                          1.01
# max                          14.99                          9.99
#
#      Wearables (in million units)  Services Revenue (in billion $)
# min                           2.0                             5.01
# max                          12.0                            19.92

# %%
df["Mac Sales (in million units)"].mean()
# Out:
# 5.55576

# %%
df["iPad Sales (in million units)"].mode()
# Out:
# 0    8.79
# Name: iPad Sales (in million units), dtype: float64

# %%
df["iPhone Sales (in million units)"].median()
# Out:
# 17.130000000000003

# %% [markdown]
# ## Dtata Preprocessing

# %%
df["Region"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Region, Length: 1000, dtype: bool

# %%
pd.set_option("display.max_rows",None)
df["Region"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
df["Region"].isnull
# Out:
# <bound method Series.isnull of 0      Greater China
# 1             Europe
# 2             Europe
# 3      Greater China
# 4       Rest of Asia
# 5      Greater China
# 6             Europe
# 7      North America
# 8      Rest of World
# 9             Europe
# 10     Greater China
# 11     Rest of World
# 12     Greater China
# 13      Rest of Asia
# 14      Rest of Asia
# 15            Europe
# 16     Greater China
# 17     Rest of World
# 18     Greater China
# 19     Rest of World
# 20     Greater China
# 21     Greater China
# 22      Rest of Asia
# 23     North America
# 24     North America
# 25            Europe
# 26     North America
# 27     Rest of World
# 28            Europe
# 29     Greater China
# 30     Rest of World
# 31     Rest of World
# 32     Rest of World
# 33     Rest of World
# 34     Rest of World
# 35            Europe
# 36     North America
# 37     Greater China
# 38     North America
# 39     Greater China
# 40     North America
# 41     North America
# ...

# %%
df.isnull().sum()
# Out:
# State                              0
# Region                             0
# iPhone Sales (in million units)    0
# iPad Sales (in million units)      0
# Mac Sales (in million units)       0
# Wearables (in million units)       0
# Services Revenue (in billion $)    0
# dtype: int64

# %%
df[df['State'].isnull()]
# Out:
# Empty DataFrame
# Columns: [State, Region, iPhone Sales (in million units), iPad Sales (in million units), Mac Sales (in million units), Wearables (in million units), Services Revenue (in billion $)]
# Index: []

# %% [markdown]
# ## Data Grouping

# %%
df.groupby("State").describe()
# Out:
#              iPhone Sales (in million units)                             \
#                                        count       mean       std   min
# State
# Australia                               43.0  14.952558  6.657316  5.15
# Beijing                                 43.0  17.610930  7.387763  5.39
# Brazil                                  46.0  18.358696  7.642407  5.49
# California                              47.0  17.943404  6.660618  5.15
# Canada                                  46.0  17.058261  7.734044  6.01
# Chongqing                               40.0  16.315000  7.235129  5.39
# Florida                                 26.0  18.450000  6.715577  5.75
# France                                  43.0  16.841628  7.360887  5.37
# Germany                                 37.0  17.793243  8.165061  5.21
# Hong Kong                               50.0  18.681200  7.415432  5.15
# Illinois                                35.0  18.801143  6.544769  6.19
# ...

# %%
df[df['Region'].isnull()]
# Out:
# Empty DataFrame
# Columns: [State, Region, iPhone Sales (in million units), iPad Sales (in million units), Mac Sales (in million units), Wearables (in million units), Services Revenue (in billion $)]
# Index: []

# %% [markdown]
# ## Slicing

# %%
df[1:7]
# Out:
#        State         Region  iPhone Sales (in million units)  \
# 1    Germany         Europe                             8.63
# 2         UK         Europe                             5.61
# 3   Shanghai  Greater China                             7.82
# 4   Thailand   Rest of Asia                            16.70
# 5  Chongqing  Greater China                            12.18
# 6         UK         Europe                            25.47
#
#    iPad Sales (in million units)  Mac Sales (in million units)  \
# 1                          14.06                          7.03
# 2                          14.09                          8.78
# 3                           7.97                          9.78
# 4                           8.13                          6.46
# 5                          10.97                          9.38
# 6                           7.41                          7.18
#
#    Wearables (in million units)  Services Revenue (in billion $)
# ...

# %%
df[2:20:3]
# Out:
#         State         Region  iPhone Sales (in million units)  \
# 2          UK         Europe                             5.61
# 5   Chongqing  Greater China                            12.18
# 8      Mexico  Rest of World                            20.80
# 11     Canada  Rest of World                            12.28
# 14      Japan   Rest of Asia                            16.91
# 17  Australia  Rest of World                             8.10
#
#     iPad Sales (in million units)  Mac Sales (in million units)  \
# 2                           14.09                          8.78
# 5                           10.97                          9.38
# 8                            6.79                          4.99
# 11                           6.65                          4.37
# 14                           6.20                          3.21
# 17                          13.87                          7.77
#
#     Wearables (in million units)  Services Revenue (in billion $)
# ...

# %%
df[['State']][13:40]
# Out:
#            State
# 13         Japan
# 14         Japan
# 15         Spain
# 16     Chongqing
# 17     Australia
# 18      Shanghai
# 19     Australia
# 20       Beijing
# 21     Hong Kong
# 22         India
# 23         Texas
# 24    California
# 25         Spain
# 26    California
# 27     Australia
# 28       Germany
# 29     Hong Kong
# 30  South Africa
# 31        Canada
# 32  South Africa
# 33        Mexico
# 34        Brazil
# 35            UK
# 36    California
# 37     Hong Kong
# 38      New York
# 39     Chongqing

# %% [markdown]
# ## Charts

# %%
df['Region'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df['Region'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Region'>

# %%
df['Region'].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Region'>

# %%
df['Region'].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df['Region'].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df['Region'].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Region'].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df['Region'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Region'>
